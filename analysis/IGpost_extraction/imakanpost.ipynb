# %%
##### Code/cell is not able to run due to json FILES not being included in the directory#####


import json 
import os
import glob
import pandas as pd

obj_dict ={}

#getting all json file into a list to iterate
os.chdir(r"C:\Users\hengd\Desktop\Year_2\Y2S2\IS434 _SAA\Project\download_images\Imakan")

extension = 'json'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_json = pd.concat([pd.read_json(f) for f in all_filenames ])

# print(all_filenames)
# print("***")
# print(combined_json)

# print(combined_json['Name'])
    

# for jsonfile in all_filenames : 
#     #open the file
#     with open(jsonfile+'.json') as f:
#         data = json.load(f)
#         print(data)


for object in combined_json['Name'] :
    #object is a dictionary
#     print(object['Name'])
    object = str(object)
    #check if in dictionary else update key-value pair
    if object in obj_dict :
        obj_dict[object] += 1
    else :
        obj_dict[object] = 1
        
##### Code/cell is not able to run due to json FILES not being included in the directory#####

# %%
list_to_remove = ['Person', 'Human', 'Face', 'Skin', 'Head', 'Hair', 'Mammal', 'Canine', 'Woman', 'Female', 'Girl'
                  , 'Clothing', 'Apparel', "Food", 'Meal', "Dish", "Plant", "Text"]

for word in list_to_remove: 
    for key in obj_dict.keys():
      if key == word:
        del obj_dict[key]
        break

# %%
wordcloud1 = WordCloud(width = 1000, height = 500, background_color = "white").generate_from_frequencies(obj_dict)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud1)

# %%
obj_dict = dict(sorted(obj_dict.items(), key=lambda item: item[1], reverse = True))
# Out:
# {'Saucer': 9, 'Pottery': 26, 'Bowl': 79, 'Bread': 54, 'Wood': 13, 'Hardwood': 6, 'Tin': 1, 'Can': 1, 'Platter': 23, 'Seasoning': 18, 'Pasta': 68, 'Ravioli': 3, 'Dumpling': 1, 'Burger': 44, 'Produce': 57, 'Chair': 8, 'Furniture': 24, 'Ice Cream': 30, 'Dessert': 59, 'Cream': 42, 'Creme': 34, 'Alcohol': 19, 'Beverage': 36, 'Drink': 33, 'Sake': 2, 'Beer': 14, 'Collage': 4, 'Advertisement': 15, 'Poster': 13, 'Home Decor': 5, 'Cushion': 5, 'Headrest': 1, 'Car': 13, 'Transportation': 14, 'Vehicle': 13, 'Car Seat': 1, 'Room': 4, 'Indoors': 9, 'Smile': 8, 'Pants': 6, 'Pillow': 3, 'Monitor': 4, 'Electronics': 7, 'Display': 3, 'Screen': 4, 'Sandwich': 4, 'Noodle': 76, 'Vermicelli': 22, 'Pizza': 20, 'Spaghetti': 11, 'Crowd': 1, 'Fruit': 17, 'Pineapple': 1, 'Festival': 1, 'Grass': 5, 'Outdoors': 40, 'Nature': 28, 'Grassland': 1, 'Field': 2, 'Evening Dress': 3, 'Lawn': 1, 'Bag': 2, 'Shopping Bag': 1, 'Tote Bag': 1, 'Hot Dog': 10, 'Sweets': 53, 'Confectionery': 49, 'Chocolate': 7, 'Latte': 4, 'Cup': 12, 'Coffee Cup': 11, 'Milk': 10, 'Juice': 8, 'Selfie': 1, 'Portrait': 2, 'Photography': 2, 'Photo': 2, 'Sunglasses': 11, 'Accessories': 18, 'Muffin': 4, 'Cake': 21, 'Icing': 12, 'Cupcake': 1, 'Wristwatch': 4, 'Stew': 21, 'Soup Bowl': 22, 'Bun': 11, 'Accessory': 10, 'Military': 1, 'Hat': 3, 'Shelf': 5, 'Market': 2, 'Tree': 8, 'Vegetation': 6, 'Woodland': 2, 'Land': 8, 'Tree Trunk': 2, 'Grove': 1, 'Oatmeal': 3, 'Breakfast': 8, 'Gun': 1, 'Weapon': 1, 'Weaponry': 1, 'Ground': 1, 'Footwear': 16, 'Pork': 5, 'Wine': 2, 'Bottle': 8, 'Wine Bottle': 2, 'Glass': 5, 'Shorts': 14, 'Sea': 6, 'Water': 21, 'Shoreline': 6, 'Beach': 3, 'Stretch': 1, 'Vegetable': 58, 'Arugula': 1, 'Sun Hat': 2, 'Hand': 3, 'Restaurant': 20, 'Food Court': 3, 'Bar Counter': 4, 'Pub': 3, 'Flower': 20, 'Blossom': 16, 'Sunflower': 1, 'Appliance': 1, 'Sprout': 17, 'Lobster': 15, 'Animal': 37, 'Sea Life': 29, 'Seafood': 16, 'Bean Sprout': 11, 'Fries': 5, 'Blonde': 2, 'Teen': 1, 'Kid': 1, 'Child': 1, 'Bronze': 1, 'Gold': 1, 'Bread Loaf': 1, 'French Loaf': 1, 'Leaf': 4, 'Fudge': 2, 'Cocoa': 1, 'Lunch': 15, 'Road': 11, 'Freeway': 2, 'Tarmac': 7, 'Highway': 2, 'Egg': 39, 'Baby': 3, 'Newborn': 2, 'Path': 2, 'Fitness': 5, 'Working Out': 5, 'Sport': 10, 'Exercise': 2, 'Long Sleeve': 4, 'Sleeve': 7, 'Birthday Cake': 8, 'Curry': 15, 'Soup': 10, 'Shoe': 17, 'Garden': 6, 'Building': 21, 'Hotel': 2, 'Pool': 1, 'City': 10, 'Urban': 10, 'Metropolis': 8, 'Office Building': 6, 'High Rise': 5, 'Palm Tree': 2, 'Architecture': 6, 'Housing': 3, 'Condo': 1, 'Apartment Building': 2, 'Menu': 2, 'Swimwear': 1, 'Bikini': 1, 'Waffle': 4, 'Strawberry': 2, 'Cafeteria': 13, 'Buffet': 8, 'Flyer': 6, 'Brochure': 5, 'Paper': 9, 'Computer Keyboard': 1, 'Computer': 2, 'Hardware': 1, 'Keyboard': 1, 'Computer Hardware': 1, 'Gym': 1, 'Arecaceae': 1, 'Flagstone': 3, 'Ruins': 1, 'Slate': 1, 'Sports': 4, 'Durian': 1, 'Cauliflower': 4, 'Clam': 6, 'Seashell': 7, 'Invertebrate': 8, 'Yard': 1, 'Park': 1, 'Bean': 6, 'Lentil': 3, 'Cookie': 2, 'Dinner': 16, 'Supper': 14, 'Porcelain': 5, 'Art': 8, 'Teapot': 3, 'Pot': 3, 'Fork': 4, 'Cutlery': 8, 'Pita': 2, 'Roast': 4, 'Toast': 3, 'French Toast': 3, 'Geranium': 1, 'Lighting': 2, 'Flare': 5, 'Light': 5, 'Oyster': 4, 'Sitting': 4, 'Cafe': 2, 'Bakery': 1, 'Shop': 2, 'Sesame': 3, 'Jar': 13, 'Bbq': 3, 'Table': 10, 'Flower Arrangement': 7, 'Mimosa': 1, 'Fir': 1, 'Sky': 6, 'Azure Sky': 1, 'Mobile Phone': 1, 'Phone': 1, 'Cell Phone': 1, 'Glasses': 7, 'Potted Plant': 7, 'Vase': 9, 'Planter': 4, 'Herbal': 1, 'Herbs': 2, 'Dining Table': 7, 'Croissant': 3, 'Milkshake': 3, 'Smoothie': 5, 'Sphere': 2, 'Tart': 1, 'Pie': 2, 'Tea': 2, 'Plastic': 1, 'Pop Bottle': 2, 'Plastic Bag': 1, 'Soda': 2, 'Orange Juice': 1, 'Pastry': 3, 'Fire': 1, 'Flame': 1, 'Cornbread': 2, 'Spoon': 4, 'Flooring': 6, 'Fashion': 2, 'Gown': 2, 'Robe': 2, 'Orange': 3, 'Citrus Fruit': 5, 'Interior Design': 8, 'Doctor': 1, 'Herring': 3, 'Fish': 5, 'Sardine': 2, 'Cocktail': 3, 'Mojito': 1, 'Mushroom': 1, 'Fungus': 2, 'Agaric': 1, 'Alphab ...
