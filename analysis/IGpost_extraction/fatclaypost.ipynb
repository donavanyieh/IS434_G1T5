# %%
##### Code/cell is not able to run due to json FILES not being included in the directory#####

import json 
import os
import glob
import pandas as pd

f_obj ={}

#getting all json file into a list to iterate
os.chdir(r"C:\Users\hengd\Desktop\Year_2\Y2S2\IS434 _SAA\Project\download_images\fatclay_postimg\post_json")

extension = 'json'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_json = pd.concat([pd.read_json(f) for f in all_filenames ])

# print(all_filenames)
# print("***")
# print(combined_json)

# print(combined_json['Name'])
    

# for jsonfile in all_filenames : 
#     #open the file
#     with open(jsonfile+'.json') as f:
#         data = json.load(f)
#         print(data)


for object in combined_json['Name'] :
    #object is a dictionary
#     print(object['Name'])
    object = str(object)
    #check if in dictionary else update key-value pair
    if object in obj_dict :
        f_obj[object] += 1
    else :
        f_obj[object] = 1
        
##### Code/cell is not able to run due to json FILES not being included in the directory#####

# %%
list_to_remove = ['Person', 'Human', 'Face', 'Skin', 'Head', 'Hair', 'Mammal', 'Canine', 'Woman', 'Female', 'Girl'
                  , 'Clothing', 'Apparel', "Food", 'Meal', "Dish", "Plant", "Text"]


for word in list_to_remove: 
    for key in f_obj.keys():
      if key == word:
        del f_obj[key]
        break

# %%
wordcloud1 = WordCloud(width = 1000, height = 500, background_color = "white").generate_from_frequencies(f_obj)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud1)

# %%
f_obj2 = dict(sorted(f_obj.items(), key=lambda item: item[1], reverse = True))
# Out:
# {'Nature': 463, 'Outdoors': 347, 'Soil': 9, 'Landscape': 21, 'Scenery': 24, 'Ground': 11, 'Countryside': 14, 'Land': 40, 'Grassland': 8, 'Field': 17, 'Animal': 208, 'Pet': 118, 'Dog': 78, 'Grass': 44, 'Poster': 169, 'Advertisement': 179, 'Flyer': 86, 'Brochure': 83, 'Paper': 113, 'Shoe': 215, 'Footwear': 228, 'Sitting': 50, 'Night': 33, 'Outer Space': 31, 'Space': 30, 'Universe': 31, 'Astronomy': 33, 'Moon': 26, 'Gray': 2, 'Affenpinscher': 4, 'Drawing': 17, 'Art': 71, 'Evening Dress': 98, 'Fashion': 123, 'Gown': 106, 'Robe': 107, 'Swimwear': 120, 'Sunglasses': 157, 'Accessories': 268, 'Accessory': 195, 'Angora': 3, 'Cat': 38, 'Kitten': 2, 'Shorts': 108, 'Night Life': 15, 'Pedestrian': 25, 'Crowd': 48, 'Urban': 66, 'Black Hair': 9, 'Jacket': 64, 'Coat': 127, 'Graffiti': 1, 'Wall': 8, 'Chair': 69, 'Furniture': 227, 'Helmet': 47, 'Pants': 149, 'Smile': 108, 'Jewelry': 47, 'Earring': 3, 'Tree Trunk': 7, 'Tree': 108, 'Finger': 65, 'Interior Design': 74, 'Indoors': 114, 'Room': 63, 'Dressing Room': 1, 'Mobile Phone': 56, 'Electronics': 109, 'Bird': 35, 'Crystal': 5, 'Skirt': 27, 'Dome': 4, 'Building': 173, 'Architecture': 76, 'Silhouette': 9, 'Flower': 89, 'Flower Arrangement': 42, 'Vase': 23, 'Jar': 23, 'Pottery': 39, 'Flower Bouquet': 33, 'Potted Plant': 16, 'Mouth': 15, 'Lip': 12, 'Sweater': 32, 'Shirt': 21, 'Dress Shirt': 2, 'Dating': 16, 'Beverage': 70, 'Drink': 60, 'Glass': 30, 'Amusement Park': 7, 'Manx': 7, 'Raspberry': 4, 'Fruit': 26, 'Water': 149, 'Lake': 5, 'Vegetation': 51, 'Fir': 20, 'Park': 4, 'Fried Chicken': 5, 'Astronaut': 2, 'Dress': 53, 'Beard': 14, 'Man': 51, 'White': 7, 'Texture': 12, 'Cell Phone': 39, 'Phone': 53, 'Arbour': 12, 'Garden': 15, 'Bikini': 34, 'Sea': 53, 'Leaf': 7, 'Droplet': 1, 'Tarmac': 29, 'Asphalt': 12, 'Road': 51, 'Car': 101, 'Transportation': 161, 'Vehicle': 154, 'Suit': 31, 'Overcoat': 60, 'Premiere': 2, 'Gravel': 3, 'Dirt Road': 3, 'Freeway': 8, 'Highway': 7, 'Blossom': 64, 'Chess': 1, 'Flagstone': 26, 'Resort': 7, 'Hotel': 14, 'City': 61, 'Town': 24, 'Downtown': 23, 'Office Building': 17, 'Summer': 14, 'Geranium': 5, 'Wood': 123, 'Meeting Room': 1, 'Conference Room': 1, 'Plywood': 32, 'Restaurant': 54, 'Cafeteria': 26, 'Flooring': 69, 'Tower': 31, 'Spire': 19, 'Steeple': 10, 'Walkway': 17, 'Path': 32, 'Abies': 7, 'Conifer': 8, 'Blonde': 35, 'Teen': 31, 'Portrait': 81, 'Photography': 81, 'Selfie': 13, 'Light': 50, 'Lighting': 38, 'Condo': 5, 'Housing': 22, 'High Rise': 17, 'Apartment Building': 5, 'Fork': 4, 'Cutlery': 11, 'Home Decor': 68, 'Corridor': 4, 'Bunker': 2, 'Automobile': 45, 'Hot Dog': 4, 'Milkshake': 1, 'Juice': 7, 'Milk': 3, 'Smoothie': 4, 'Fire': 7, 'Flame': 5, 'Lamp': 8, 'Bonfire': 4, 'Bicycle': 11, 'Bike': 4, 'Sport': 337, 'Sports': 50, 'People': 81, 'Team Sport': 21, 'Team': 20, 'Purple': 7, 'Working Out': 230, 'Fitness': 280, 'Jogging': 2, 'Elephant': 2, 'Play Area': 3, 'Playground': 2, 'Jeans': 42, 'Denim': 24, 'Label': 24, 'Toothpaste': 1, 'Metropolis': 39, 'Panoramic': 11, 'Bathtub': 8, 'Tub': 11, 'Fireplace': 4, 'Alcohol': 42, 'Beer': 30, 'Wine': 7, 'Kid': 25, 'Back': 23, 'Petal': 12, 'Anther': 1, 'Ice': 19, 'Snow': 21, 'Frost': 2, 'Saucer': 12, 'Green': 3, 'Gemstone': 7, 'Sphere': 12, 'Text Message': 6, 'Bottle': 24, 'Wine Bottle': 3, 'Motorcycle': 22, 'Wheel': 76, 'Motor Scooter': 5, 'Scooter': 3, 'Bed': 10, 'Chicken': 1, 'Fowl': 1, 'Poultry': 1, 'Clock Tower': 7, 'Sleeve': 199, 'Watercraft': 12, 'Vessel': 8, 'Waterfront': 18, 'Pier': 11, 'Port': 2, 'Marina': 2, 'Boat': 16, 'Miniskirt': 3, 'Photo': 52, 'Snowman': 2, 'Winter': 8, 'Couch': 62, 'Cushion': 61, 'Painting': 21, 'Dragon': 2, 'Pencil': 1, 'Tape': 1, 'Bowl': 28, 'Tabletop': 11, 'Dessert': 81, 'Chocolate': 9, 'Sweets': 46, 'Confectionery': 36, 'Ice Cream': 24, 'Cream': 47, 'Fudge': 4, 'Guitar': 11, 'Leisure Activities': 32, 'Musical Instrument': 20, 'Musician': 9, 'Guitarist': 2, 'Performer': 8, 'Hat': 52, 'Hockey': 2, 'Rink': 3, 'Ice Skating': 7, 'Ice Hockey': 2, 'Studio': 3, 'Bathroom': 5, 'Shark': 1, 'Sea Li ...
