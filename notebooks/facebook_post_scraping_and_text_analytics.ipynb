# %% [markdown]
# # Facebook post scraping and Text Analytics

# %% [markdown]
# Post scraping from Facebook.

# %%
pip install git+https://github.com/kevinzg/facebook-scraper.git
# Out:
# Collecting git+https://github.com/kevinzg/facebook-scraper.git
#   Cloning https://github.com/kevinzg/facebook-scraper.git to c:\users\kytan\appdata\local\temp\pip-req-build-n4xzmtg8
#   Resolved https://github.com/kevinzg/facebook-scraper.git to commit 7357da290aa1454bafe74418fa90427a274f1e49
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting requests-html<0.11.0,>=0.10.0
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting demjson3<4.0.0,>=3.0.5
#   Downloading demjson3-3.0.5.tar.gz (132 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dateparser<2.0.0,>=1.0.0
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\kytan\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.53) (2021.4.4)
# Requirement already satisfied: pytz in c:\users\kytan\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.53) (2021.1)
# Collecting tzlocal
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: python-dateutil in c:\users\kytan\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.53) (2.8.1)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\kytan\anaconda3\lib\site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (2.25.1)
# Collecting certifi>=2021
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.1-cp38-cp38-win_amd64.whl (97 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\kytan\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\kytan\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (3.10.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\kytan\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (4.62.3)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\kytan\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (1.26.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\kytan\anaconda3\lib\site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (4.9.3)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in c:\users\kytan\anaconda3\lib\site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (4.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\kytan\anaconda3\lib\site-packages (from python-dateutil->dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.53) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\kytan\anaconda3\lib\site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kytan\anaconda3\lib\site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (2.10)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\kytan\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (3.4.1)
# Requirement already satisfied: colorama in c:\users\kytan\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (0.4.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kytan\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.53) (2.2.1)
# Building wheels for collected packages: facebook-scraper, demjson3, bs4, fake-useragent, parse
#   Building wheel for facebook-scraper (pyproject.toml): startedNote: you may need to restart the kernel to use updated packages.
#   Building wheel for facebook-scraper (pyproject.toml): finished with status 'done'
#   Created wheel for facebook-scraper: filename=facebook_scraper-0.2.53-py3-none-any.whl size=42071 sha256=5cd292484230dcb4c36d319596e17020fdd323063fe891dfb9a8280d2dcc7871
#   Stored in directory: C:\Users\kytan\AppData\Local\Temp\pip-ephem-wheel-cache-v6zcbl0x\wheels\aa\39\09\742085e70fef89aa192a999628711df1c08cdbf1690b9989f8
#   Building wheel for demjson3 (setup.py): started
#   Building wheel for demjson3 (setup.py): finished with status 'done'
#   Created wheel for demjson3: filename=demjson3-3.0.5-py3-none-any.whl size=76061 sha256=808926f0017e7d125130b06f80a168f3b3f5a4bb7f363478e4307e2d3f24647c
#   Stored in directory: c:\users\kytan\appdata\local\pip\cache\wheels\b9\7f\83\c60451302e62feb81c84a1455e9a42ccf348e6434ce173047b
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=39c9db77cbd8b6a2f1341e670233cfd2ae4444eb0d4fc7b9f6701d751b94430a
#   Stored in directory: c:\users\kytan\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13486 sha256=eb06616bbb1e54eaed2066860e1246f58558bbc36a15fba45cb6c57742e2c206
#   Stored in directory: c:\users\kytan\appdata\local\pip\cache\wheels\a0\b8\b7\8c942b2c5be5158b874a88195116b05ad124bac795f6665e65
#
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24581 sha256=ebff88d0d209b8cbb3661d8ad0741d72501bc4be8d3442b81b98ee258b95dada
#   Stored in directory: c:\users\kytan\appdata\local\pip\cache\wheels\e5\33\1f\68392720485b3ecf125a69e700baaab7624616deedea2fa6e2
# Successfully built facebook-scraper demjson3 bs4 fake-useragent parse
# Installing collected packages: tzdata, backports.zoneinfo, websockets, pytz-deprecation-shim, pyee, cssselect, certifi, w3lib, tzlocal, pyquery, pyppeteer, parse, fake-useragent, bs4, requests-html, demjson3, dateparser, facebook-scraper
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
# Successfully installed backports.zoneinfo-0.2.1 bs4-0.0.1 certifi-2021.10.8 cssselect-1.1.0 dateparser-1.1.0 demjson3-3.0.5 facebook-scraper-0.2.53 fake-useragent-0.1.11 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 pytz-deprecation-shim-0.1.0.post0 requests-html-0.10.0 tzdata-2021.5 tzlocal-4.1 w3lib-1.22.0 websockets-10.1
#   Running command git clone --filter=blob:none -q https://github.com/kevinzg/facebook-scraper.git 'C:\Users\kytan\AppData\Local\Temp\pip-req-build-n4xzmtg8'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\kytan\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install facebook-scrapper

# %%
# Import necessary libraries
from facebook_scraper import get_posts
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns = [])

# %%
# Start to collect Facebook post data by facebook_scraper library

# use your own cookies --> you can add chrome extension getcookies to save cookies in txt file 
for post in get_posts('fukudonsg', cookies='facebook.com_cookies2.txt', extra_info=True, pages=8, options={"comments": True}):
    post_entry = post
    fb_post_df = pd.DataFrame.from_dict(post_entry, orient='index')
    fb_post_df = fb_post_df.transpose()
    post_df_full = post_df_full.append(fb_post_df)
    print(post['post_id']+' get')
# Out:
# 430656518800944 get
# C:\Users\kytan\anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py:795: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(
# C:\Users\kytan\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# 427687089097887 get
# 425210366012226 get
# 421822059684390 get
# 420517959814800 get
# 419646406568622 get
# 418761639990432 get
# 418118486721414 get
# 415699836963279 get
# 413257057207557 get
# 411993977333865 get
# 407776717755591 get
# 407201737813089 get
# 404827634717166 get
# 403586801507916 get
# 401825905017339 get
# 400625021804094 get
# 398699378663325 get
# 398066788726584 get
# 394841922382404 get
# 394831389050124 get
# 391400786059851 get
# 391400369393226 get
# 391400019393261 get
# 388998502966746 get
# 378888587311071 get
# 357454752787788 get
# 319410273258903 get
# 294832585716672 get

# %%
# Check dataframe information, 47 data columns of Facebook post are being scraped
post_df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 0
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        17 non-null     object
#  1   text                           17 non-null     object
#  2   post_text                      17 non-null     object
#  3   shared_text                    17 non-null     object
#  4   time                           17 non-null     datetime64[ns]
#  5   timestamp                      4 non-null      object
#  6   image                          14 non-null     object
#  7   image_lowquality               17 non-null     object
#  8   images                         17 non-null     object
#  9   images_description             17 non-null     object
#  10  images_lowquality              17 non-null     object
#  11  images_lowquality_description  17 non-null     object
#  12  video                          3 non-null      object
#  13  video_duration_seconds         0 non-null      object
#  14  video_height                   0 non-null      object
#  15  video_id                       3 non-null      object
#  16  video_quality                  0 non-null      object
#  17  video_size_MB                  0 non-null      object
#  18  video_thumbnail                3 non-null      object
#  19  video_watches                  0 non-null      object
#  20  video_width                    0 non-null      object
#  21  likes                          17 non-null     object
#  22  comments                       17 non-null     object
#  23  shares                         17 non-null     object
#  24  post_url                       17 non-null     object
#  25  link                           0 non-null      object
#  26  links                          17 non-null     object
#  27  user_id                        17 non-null     object
#  28  username                       17 non-null     object
#  29  user_url                       17 non-null     object
#  30  is_live                        17 non-null     object
#  31  factcheck                      0 non-null      object
#  32  shared_post_id                 1 non-null      object
#  33  shared_time                    1 non-null      object
#  34  shared_user_id                 1 non-null      object
#  35  shared_username                1 non-null      object
#  36  shared_post_url                1 non-null      object
#  37  available                      17 non-null     object
#  38  comments_full                  17 non-null     object
#  39  reactors                       17 non-null     object
#  40  w3_fb_url                      17 non-null     object
#  41  reactions                      17 non-null     object
#  42  reaction_count                 17 non-null     object
#  43  with                           9 non-null      object
#  44  page_id                        17 non-null     object
#  45  sharers                        0 non-null      object
#  46  image_id                       6 non-null      object
#  47  image_ids                      17 non-null     object
#  48  was_live                       17 non-null     object
#  49  header                         9 non-null      object
#  50  fetched_time                   17 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), object(49)
# memory usage: 6.9+ KB

# %%
# Display header of dataframe
post_df_full.head()
# Out:
#            post_id                                               text  \
# 0  430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 0  427687089097887  Let us bring you behind the scenes and show yo...
# 0  425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 0  421822059684390  We’ve heard you! We are pleased to finally ann...
# 0  420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                                            post_text shared_text  \
# 0  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 0  Let us bring you behind the scenes and show yo...
# 0  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 0  We’ve heard you! We are pleased to finally ann...
# 0  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                  time timestamp  \
# 0 2022-02-12 14:22:59      None
# 0 2022-02-07 15:20:00      None
# 0 2022-02-03 11:24:00      None
# 0 2022-01-28 18:04:00      None
# 0 2022-01-26 13:37:00      None
#
#                                                image  \
# 0                                               None
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                     image_lowquality  \
# 0  https://scontent-xsp1-3.xx.fbcdn.net/v/t15.525...
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 0  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                               images  \
# 0                                                 []
# 0  [https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30...
# 0  [https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30...
# 0  [https://scontent-xsp1-3.xx.fbcdn.net/v/t39.30...
# 0  [https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30...
#
#                                   images_description  ...  \
# 0                                                 []  ...
# 0  [May be an image of food and text that says 'P...  ...
# 0  [May be an image of food and text that says 'F...  ...
# 0                          [May be an image of text]  ...
# 0  [May be an image of food and text, May be an i...  ...
#
#                  reactions reaction_count  \
# 0              {'like': 1}              1
# 0  {'like': 14, 'love': 1}             15
# 0              {'like': 9}              9
# 0              {'like': 9}              9
# 0              {'like': 4}              4
#
#                                                 with          page_id sharers  \
# 0                                               None  100762711790328    None
# 0  [{'name': 'Fukudon', 'link': '/fukudonsg/?__tn...  100762711790328    None
# 0                                               None  100762711790328    None
# 0  [{'name': 'Fukudon', 'link': '/fukudonsg/?__tn...  100762711790328    None
# 0                                               None  100762711790328    None
#
#           image_id          image_ids was_live               fetched_time  \
# 0             None                 []    False 2022-02-12 16:23:03.440178
# 0             None                 []    False 2022-02-12 16:23:10.946446
# 0  425210336012229  [425210336012229]    False 2022-02-12 16:23:13.145496
# 0  421822043017725  [421822043017725]    False 2022-02-12 16:23:15.559240
# 0             None                 []    False 2022-02-12 16:23:20.549986
#
#                    header
# 0                     NaN
# 0  Fukudon is at Fukudon.
# 0                     NaN
# 0  Fukudon is at Fukudon.
# 0                     NaN
#
# [5 rows x 51 columns]

# %%
# Save dataframe into csv file
post_df_full.to_csv(r'fb_scrapped_data.csv', index = False)

# %%
# Perform basic line plot to visualize post datetime vs likes
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full['likes'], marker="o")
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
# Perform basic line plot to visualize post datetime vs likes, shares and comments
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full['likes'], label = "Likes", marker="o")
ax.plot(post_df_full['time'], post_df_full['shares'], label = "Shares", marker="s")
ax.plot(post_df_full['time'], post_df_full['comments'], label = "Comments", marker="*")
plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
# Reload dataframe from csv file
post_df_full_csv = pd.read_csv("fb_scrapped_data.csv")
post_df_full_csv['time'] = pd.to_datetime(post_df_full_csv['time'])

# %%
# Display header of dataframe
post_df_full_csv.head()
# Out:
#            post_id                                               text  \
# 0  430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 1  427687089097887  Let us bring you behind the scenes and show yo...
# 2  425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 3  421822059684390  We’ve heard you! We are pleased to finally ann...
# 4  420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                                            post_text shared_text  \
# 0  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...         NaN
# 1  Let us bring you behind the scenes and show yo...         NaN
# 2  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...         NaN
# 3  We’ve heard you! We are pleased to finally ann...         NaN
# 4  🐯🧧 Let us usher in a Roarsome Lunar New Year t...         NaN
#
#                  time  timestamp  \
# 0 2022-02-12 14:25:19        NaN
# 1 2022-02-07 15:20:00        NaN
# 2 2022-02-03 11:24:00        NaN
# 3 2022-01-28 18:04:00        NaN
# 4 2022-01-26 13:37:00        NaN
#
#                                                image  \
# 0                                                NaN
# 1  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                     image_lowquality  \
# 0  https://scontent-xsp1-3.xx.fbcdn.net/v/t15.525...
# 1  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                               images  \
# 0                                                 []
# 1  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 2  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 3  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 4  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
#
#                                   images_description  ...  \
# 0                                                 []  ...
# 1  ["May be an image of food and text that says '...  ...
# 2  ["May be an image of food and text that says '...  ...
# 3                        ['May be an image of text']  ...
# 4  ['May be an image of food and text', "May be a...  ...
#
#                  reactions reaction_count  \
# 0              {'like': 1}            1.0
# 1  {'like': 14, 'love': 1}           15.0
# 2              {'like': 9}            9.0
# 3              {'like': 9}            9.0
# 4              {'like': 4}            4.0
#
#                                                 with          page_id  \
# 0                                                NaN  100762711790328
# 1  [{'name': 'Fukudon', 'link': '/fukudonsg/?__tn...  100762711790328
# 2                                                NaN  100762711790328
# 3  [{'name': 'Fukudon', 'link': '/fukudonsg/?__tn...  100762711790328
# 4                                                NaN  100762711790328
#
#    sharers      image_id            image_ids  was_live  \
# 0      NaN           NaN                   []     False
# 1      NaN           NaN                   []     False
# 2      NaN  4.252103e+14  ['425210336012229']     False
# 3      NaN  4.218220e+14  ['421822043017725']     False
# 4      NaN           NaN                   []     False
#
#                  fetched_time                  header
# 0  2022-02-12 15:25:24.093008                     NaN
# 1  2022-02-12 15:25:30.899869  Fukudon is at Fukudon.
# 2  2022-02-12 15:25:34.930998                     NaN
# 3  2022-02-12 15:25:36.984890  Fukudon is at Fukudon.
# 4  2022-02-12 15:25:41.278896                     NaN
#
# [5 rows x 51 columns]

# %%
# Check dataframe information, 47 data columns in total, no change
# post_df_full_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        18 non-null     int64
#  1   text                           18 non-null     object
#  2   post_text                      18 non-null     object
#  3   shared_text                    16 non-null     object
#  4   time                           18 non-null     datetime64[ns]
#  5   timestamp                      18 non-null     int64
#  6   image                          16 non-null     object
#  7   image_lowquality               18 non-null     object
#  8   images                         18 non-null     object
#  9   images_description             18 non-null     object
#  10  images_lowquality              18 non-null     object
#  11  images_lowquality_description  18 non-null     object
#  12  video                          2 non-null      object
#  13  video_duration_seconds         0 non-null      float64
#  14  video_height                   0 non-null      float64
#  15  video_id                       2 non-null      float64
#  16  video_quality                  0 non-null      float64
#  17  video_size_MB                  0 non-null      float64
#  18  video_thumbnail                2 non-null      object
#  19  video_watches                  0 non-null      float64
#  20  video_width                    0 non-null      float64
#  21  likes                          18 non-null     int64
#  22  comments                       18 non-null     int64
#  23  shares                         18 non-null     int64
#  24  post_url                       18 non-null     object
#  25  link                           18 non-null     object
#  26  links                          18 non-null     object
#  27  user_id                        18 non-null     int64
#  28  username                       18 non-null     object
#  29  user_url                       18 non-null     object
#  30  is_live                        18 non-null     bool
#  31  factcheck                      0 non-null      float64
#  32  shared_post_id                 0 non-null      float64
#  33  shared_time                    0 non-null      float64
#  34  shared_user_id                 0 non-null      float64
#  35  shared_username                0 non-null      float64
#  36  shared_post_url                0 non-null      float64
#  37  available                      18 non-null     bool
#  38  comments_full                  18 non-null     object
#  39  reactors                       18 non-null     object
#  40  w3_fb_url                      18 non-null     object
#  41  reactions                      18 non-null     object
#  42  reaction_count                 18 non-null     int64
#  43  with                           0 non-null      float64
#  44  image_id                       0 non-null      float64
#  45  image_ids                      18 non-null     object
#  46  fetched_time                   18 non-null     object
# dtypes: bool(2), datetime64[ns](1), float64(15), int64(7), object(22)
# memory usage: 6.5+ KB

# %%
# Select and display post_id & reactions columns. In reactions column, there are various type of reactions
# in json/dictionary format.
post_df_full_csv[['post_id', 'reactions']]
# Out:
#             post_id                                     reactions
# 0   430656518800944                                   {'like': 1}
# 1   427687089097887                       {'like': 14, 'love': 1}
# 2   425210366012226                                   {'like': 9}
# 3   421822059684390                                   {'like': 9}
# 4   420517959814800                                   {'like': 4}
# 5   419646406568622                        {'like': 3, 'love': 1}
# 6   418761639990432                        {'like': 18, 'wow': 1}
# 7   418118486721414                                   {'like': 3}
# 8   415699836963279                                   {'like': 7}
# 9   413257057207557                                   {'like': 6}
# 10  411993977333865                                   {'like': 4}
# 11  407776717755591                       {'like': 39, 'love': 1}
# 12  407201737813089                                   {'like': 9}
# 13  404827634717166                                  {'like': 12}
# 14  403586801507916                                   {'like': 9}
# 15  401825905017339                       {'like': 27, 'love': 1}
# 16  400625021804094                                  {'like': 10}
# 17  398699378663325                                   {'like': 8}
# 18  398066788726584                                  {'like': 12}
# 19  394841922382404                                   {'like': 2}
# 20  394831389050124                                   {'like': 7}
# 21  391400786059851                       {'like': 34, 'love': 1}
# 22  391400369393226            {'like': 39, 'love': 1, 'care': 1}
# 23  391400019393261                       {'like': 45, 'haha': 2}
# 24  388998502966746                       {'like': 17, 'love': 1}
# 25  378888587311071                       {'like': 19, 'love': 2}
# 26  357454752787788            {'like': 18, 'love': 1, 'care': 1}
# 27  319410273258903                                   {'like': 1}
# 28  294832585716672  {'like': 31, 'love': 2, 'wow': 1, 'care': 1}

# %%
# Expand reactions columns into multiple columns
post_df_full_csv['reactions'] = post_df_full_csv['reactions'].apply(lambda x : dict(eval(x)) )
post_df_full_csv_reactions = post_df_full_csv['reactions'].apply(pd.Series )

# %%
# Merge expanded columns into dataframe
post_df_full_csv_with_reactions = pd.concat([post_df_full_csv, post_df_full_csv_reactions], axis=1).drop('reactions', axis=1)

# %%
# Display header of dataframe
post_df_full_csv_with_reactions.head()
# Out:
#            post_id                                               text  \
# 0  430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 1  427687089097887  Let us bring you behind the scenes and show yo...
# 2  425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 3  421822059684390  We’ve heard you! We are pleased to finally ann...
# 4  420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                                            post_text shared_text  \
# 0  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...         NaN
# 1  Let us bring you behind the scenes and show yo...         NaN
# 2  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...         NaN
# 3  We’ve heard you! We are pleased to finally ann...         NaN
# 4  🐯🧧 Let us usher in a Roarsome Lunar New Year t...         NaN
#
#                  time  timestamp  \
# 0 2022-02-12 14:22:59        NaN
# 1 2022-02-07 15:20:00        NaN
# 2 2022-02-03 11:24:00        NaN
# 3 2022-01-28 18:04:00        NaN
# 4 2022-01-26 13:37:00        NaN
#
#                                                image  \
# 0                                                NaN
# 1  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                     image_lowquality  \
# 0  https://scontent-xsp1-3.xx.fbcdn.net/v/t15.525...
# 1  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
#
#                                               images  \
# 0                                                 []
# 1  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 2  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 3  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 4  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
#
#                                   images_description  ...      image_id  \
# 0                                                 []  ...           NaN
# 1  ["May be an image of food and text that says '...  ...           NaN
# 2  ["May be an image of food and text that says '...  ...  4.252103e+14
# 3                        ['May be an image of text']  ...  4.218220e+14
# 4  ['May be an image of food and text', "May be a...  ...           NaN
#
#              image_ids was_live                fetched_time  \
# 0                   []    False  2022-02-12 16:23:03.440178
# 1                   []    False  2022-02-12 16:23:10.946446
# 2  ['425210336012229']    False  2022-02-12 16:23:13.145496
# 3  ['421822043017725']    False  2022-02-12 16:23:15.559240
# 4                   []    False  2022-02-12 16:23:20.549986
#
#                    header  like  love  wow care  haha
# 0                     NaN   1.0   NaN  NaN  NaN   NaN
# 1  Fukudon is at Fukudon.  14.0   1.0  NaN  NaN   NaN
# 2                     NaN   9.0   NaN  NaN  NaN   NaN
# 3  Fukudon is at Fukudon.   9.0   NaN  NaN  NaN   NaN
# 4                     NaN   4.0   NaN  NaN  NaN   NaN
#
# [5 rows x 55 columns]

# %%
# Check dataframe information, 53 data columns in total, 6 columns are being added
post_df_full_csv_with_reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        18 non-null     int64
#  1   text                           18 non-null     object
#  2   post_text                      18 non-null     object
#  3   shared_text                    16 non-null     object
#  4   time                           18 non-null     datetime64[ns]
#  5   timestamp                      18 non-null     int64
#  6   image                          16 non-null     object
#  7   image_lowquality               18 non-null     object
#  8   images                         18 non-null     object
#  9   images_description             18 non-null     object
#  10  images_lowquality              18 non-null     object
#  11  images_lowquality_description  18 non-null     object
#  12  video                          2 non-null      object
#  13  video_duration_seconds         0 non-null      float64
#  14  video_height                   0 non-null      float64
#  15  video_id                       2 non-null      float64
#  16  video_quality                  0 non-null      float64
#  17  video_size_MB                  0 non-null      float64
#  18  video_thumbnail                2 non-null      object
#  19  video_watches                  0 non-null      float64
#  20  video_width                    0 non-null      float64
#  21  likes                          18 non-null     int64
#  22  comments                       18 non-null     int64
#  23  shares                         18 non-null     int64
#  24  post_url                       18 non-null     object
#  25  link                           18 non-null     object
#  26  links                          18 non-null     object
#  27  user_id                        18 non-null     int64
#  28  username                       18 non-null     object
#  29  user_url                       18 non-null     object
#  30  is_live                        18 non-null     bool
#  31  factcheck                      0 non-null      float64
#  32  shared_post_id                 0 non-null      float64
#  33  shared_time                    0 non-null      float64
#  34  shared_user_id                 0 non-null      float64
#  35  shared_username                0 non-null      float64
#  36  shared_post_url                0 non-null      float64
#  37  available                      18 non-null     bool
#  38  comments_full                  18 non-null     object
#  39  reactors                       18 non-null     object
#  40  w3_fb_url                      18 non-null     object
#  41  reaction_count                 18 non-null     int64
#  42  with                           0 non-null      float64
#  43  image_id                       0 non-null      float64
#  44  image_ids                      18 non-null     object
#  45  fetched_time                   18 non-null     object
#  46  like                           18 non-null     float64
#  47  love                           17 non-null     float64
#  48  haha                           17 non-null     float64
#  49  wow                            17 non-null     float64
#  50  sad                            14 non-null     float64
#  51  angry                          16 non-null     float64
#  52  care                           15 non-null     float64
# dtypes: bool(2), datetime64[ns](1), float64(22), int64(7), object(21)
# memory usage: 7.3+ KB

# %%
post_df_full_csv_with_reactions
# Out:
#             post_id                                               text  \
# 0   430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 1   427687089097887  Let us bring you behind the scenes and show yo...
# 2   425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 3   421822059684390  We’ve heard you! We are pleased to finally ann...
# 4   420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
# 5   419646406568622  OutlandishSG\nJanuary 24 at 8:00 PM ·\n\nJapan...
# 6   418761639990432  🧧Introducing to you our Roaring Combo this Lun...
# 7   418118486721414  In Celebration of Lunar New Year 2022, kindly ...
# 8   415699836963279  Take a look at our Shoyu Glazed Salmon Don, a ...
# 9   413257057207557  A unique take on our classic Chicken Karaage, ...
# 10  411993977333865  Simple but mouth-watering is the perfect way t...
# 11  407776717755591  Stay Home and Makan! 🤤\n\nFeast with your fami...
# 12  407201737813089  Wondering how to get to our Punggol outlet by ...
# 13  404827634717166  We would like to thank each and everyone of yo...
# 14  403586801507916  Wondering how to get to our Punggol outlet by ...
# 15  401825905017339  Aburi Miso Salmon Don w/ Pickled Cucumber, Car...
# 16  400625021804094  From all of us at Fukudon, we wish everyone a ...
# 17  398699378663325  Merry Christmas and Happy New Year to everyone...
# 18  398066788726584  Merry Christmas and Happy Holidays to all from...
# 19  394841922382404                     Fukudon updated their address.
# 20  394831389050124  We are proud to announce Fúkudon's grand openi...
# 21  391400786059851  We have heard you!\nA popular blackboard menu ...
# 22  391400369393226  Finally, the news you’ve all been waiting for....
# 23  391400019393261  A fan favourite, our Chicken Oyakodon is the p...
# 24  388998502966746  Something special is in the works for Fúkudon!...
# 25  378888587311071  Satay Pork Collar Onigiri, Homemade Achar and ...
# 26  357454752787788  Our Blackboards are back by popular demands! 🙌...
# 27  319410273258903  Introducing to you our newest BLACKBOARD menu ...
# 28  294832585716672  It's always a delightful moment when neighbori...
#
#                                             post_text  \
# 0   🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 1   Let us bring you behind the scenes and show yo...
# 2   🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 3   We’ve heard you! We are pleased to finally ann...
# 4   🐯🧧 Let us usher in a Roarsome Lunar New Year t...
# 5                                                 NaN
# 6   🧧Introducing to you our Roaring Combo this Lun...
# 7   In Celebration of Lunar New Year 2022, kindly ...
# 8   Take a look at our Shoyu Glazed Salmon Don, a ...
# 9   A unique take on our classic Chicken Karaage, ...
# 10  Simple but mouth-watering is the perfect way t...
# 11  Stay Home and Makan! 🤤\n\nFeast with your fami...
# 12  Wondering how to get to our Punggol outlet by ...
# 13  We would like to thank each and everyone of yo...
# 14  Wondering how to get to our Punggol outlet by ...
# 15  Aburi Miso Salmon Don w/ Pickled Cucumber, Car...
# 16  From all of us at Fukudon, we wish everyone a ...
# 17  Merry Christmas and Happy New Year to everyone...
# 18  Merry Christmas and Happy Holidays to all from...
# 19                                                NaN
# 20  We are proud to announce Fúkudon's grand openi...
# 21  We have heard you!\nA popular blackboard menu ...
# 22  Finally, the news you’ve all been waiting for....
# 23  A fan favourite, our Chicken Oyakodon is the p...
# 24  Something special is in the works for Fúkudon!...
# 25  Satay Pork Collar Onigiri, Homemade Achar and ...
# 26  Our Blackboards are back by popular demands! 🙌...
# 27  Introducing to you our newest BLACKBOARD menu ...
# 28  It's always a delightful moment when neighbori...
#
#                                           shared_text                time  \
# 0                                                 NaN 2022-02-12 14:22:59
# 1                                                 NaN 2022-02-07 15:20:00
# 2                                                 NaN 2022-02-03 11:24:00
# 3                                                 NaN 2022-01-28 18:04:00
# 4                                                 NaN 2022-01-26 13:37:00
# 5   OutlandishSG\nJanuary 24 at 8:00 PM ·\n\nJapan... 2022-01-25 01:52:15
# 6                                                 NaN 2022-01-23 16:01:56
# 7                                                 NaN 2022-01-22 15:33:02
# 8                                                 NaN 2022-01-18 15:11:35
# 9                                                 NaN 2022-01-14 14:26:00
# 10                                                NaN 2022-01-12 16:52:00
# 11                                                NaN 2022-01-05 15:49:00
# 12                                                NaN 2022-01-04 16:16:00
# 13                                                NaN 2021-12-31 18:57:00
# 14                                                NaN 2021-12-29 16:58:00
# 15                                                NaN 2021-12-26 16:16:00
# 16                                                NaN 2021-12-24 18:40:00
# 17                                                NaN 2021-12-21 16:53:18
# 18                                                NaN 2021-12-20 16:10:16
# 19                     Fukudon updated their address. 2021-12-15 08:46:26
# 20                                                NaN 2021-12-15 08:12:30
# 21                                                NaN 2021-12-09 16:38:00
# 22                                                NaN 2021-12-09 16:38:00
# 23                                                NaN 2021-12-09 16:37:00
# 24                                                NaN 2021-12-05 18:27:00
# 25                                                NaN 2021-11-19 14:17:00
# 26                                                NaN 2021-10-17 12:13:00
# 27                                                NaN 2021-08-20 13:46:00
# 28                                                NaN 2021-07-14 16:53:00
#
#        timestamp                                              image  \
# 0            NaN                                                NaN
# 1            NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2            NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3            NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4            NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 5   1.643047e+09                                                NaN
# 6   1.642925e+09  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 7   1.642837e+09  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 8   1.642490e+09  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 9            NaN  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 10           NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 11           NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 12           NaN                                                NaN
# 13           NaN  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 14           NaN                                                NaN
# 15           NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 16           NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 17  1.640077e+09  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 18  1.639988e+09  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 19  1.639529e+09                                                NaN
# 20  1.639527e+09  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 21           NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 22           NaN  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 23           NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 24           NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 25           NaN  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 26           NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 27           NaN  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 28           NaN  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
#
#                                      image_lowquality  \
# 0   https://scontent-xsp1-3.xx.fbcdn.net/v/t15.525...
# 1   https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 2   https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 3   https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 4   https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 5   https://scontent-xsp1-1.xx.fbcdn.net/v/t15.525...
# 6   https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 7   https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 8   https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 9   https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 10  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 11  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 12  https://scontent-xsp1-2.xx.fbcdn.net/v/t15.525...
# 13  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 14  https://scontent-xsp1-1.xx.fbcdn.net/v/t15.525...
# 15  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 16  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 17  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 18  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 19  https://scontent-xsp1-2.xx.fbcdn.net/v/t1.6435...
# 20  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 21  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 22  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
# 23  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 24  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 25  https://scontent-xsp1-3.xx.fbcdn.net/v/t39.308...
# 26  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 27  https://scontent-xsp1-2.xx.fbcdn.net/v/t39.308...
# 28  https://scontent-xsp1-1.xx.fbcdn.net/v/t39.308...
#
#                                                images  \
# 0                                                  []
# 1   ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 2   ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 3   ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 4   ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 5                                                  []
# 6   ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 7   ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 8   ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 9   ['https://scontent-xsp1-1.xx.fbcdn.net/v/t39.3...
# 10  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 11  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 12                                                 []
# 13  ['https://scontent-xsp1-1.xx.fbcdn.net/v/t39.3...
# 14                                                 []
# 15  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 16  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 17  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 18  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 19                                                 []
# 20  ['https://scontent-xsp1-1.xx.fbcdn.net/v/t39.3...
# 21  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 22  ['https://scontent-xsp1-1.xx.fbcdn.net/v/t39.3...
# 23  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 24  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 25  ['https://scontent-xsp1-3.xx.fbcdn.net/v/t39.3...
# 26  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 27  ['https://scontent-xsp1-2.xx.fbcdn.net/v/t39.3...
# 28  ['https://scontent-xsp1-1.xx.fbcdn.net/v/t39.3...
#
#                                    images_description  ...      image_id  \
# 0                                                  []  ...           NaN
# 1   ["May be an image of food and text that says '...  ...           NaN
# 2   ["May be an image of food and text that says '...  ...  4.252103e+14
# 3                         ['May be an image of text']  ...  4.218220e+14
# 4   ['May be an image of food and text', "May be a...  ...           NaN
# 5                                                  []  ...           NaN
# 6   ["May be an image of food, indoor and text tha...  ...           NaN
# 7   ["May be an image of text that says 'FÚKU DON ...  ...  4.181185e+14
# 8   ['May be an image of food and text', 'May be a...  ...           NaN
# 9   ['May be an image of food and text', 'May be a...  ...           NaN
# 10  ["May be an image of food and text that says '...  ...           NaN
# 11  ["May be an image of food and text that says '...  ...           NaN
# 12                                                 []  ...           NaN
# 13                        ['May be an image of text']  ...  4.048276e+14
# 14                                                 []  ...           NaN
# 15  ['May be an image of food and text', "May be a...  ...           NaN
# 16               ['May be an image of food and text']  ...  4.006250e+14
# 17               ['May be an image of food and text']  ...  3.986994e+14
# 18                        ['May be an image of text']  ...  3.980668e+14
# 19                                                 []  ...           NaN
# 20  ["May be an image of food and text that says '...  ...  3.948314e+14
# 21  ['May be an image of food and text', 'May be a...  ...           NaN
# 22  ["May be an image of indoor and text that says...  ...  3.914004e+14
# 23  ['May be an image of food and text', 'May be a...  ...           NaN
# 24     ['May be an image of fire, outdoors and text']  ...  3.889983e+14
# 25                        ['May be an image of food']  ...  3.788886e+14
# 26             ['May be an image of food and indoor']  ...  3.574547e+14
# 27                        ['May be an image of food']  ...  3.194102e+14
# 28             ['May be an image of food and indoor']  ...  2.948326e+14
#
#               image_ids was_live                fetched_time  \
# 0                    []    False  2022-02-12 16:23:03.440178
# 1                    []    False  2022-02-12 16:23:10.946446
# 2   ['425210336012229']    False  2022-02-12 16:23:13.145496
# 3   ['421822043017725']    False  2022-02-12 16:23:15.559240
# 4                    []    False  2022-02-12 16:23:20.549986
# 5                    []    False  2022-02-12 16:23:22.566545
# 6                    []    False  2022-02-12 16:23:27.127614
# 7   ['418118473388082']    False  2022-02-12 16:23:29.513796
# 8                    []    False  2022-02-12 16:23:37.040564
# 9                    []    False  2022-02-12 16:23:43.799573
# 10                   []    False  2022-02-12 16:23:48.670398
# 11                   []    False  2022-02-12 16:23:57.267616
# 12                   []    False  2022-02-12 16:24:02.124683
# 13  ['404827608050502']    False  2022-02-12 16:24:05.944416
# 14                   []    False  2022-02-12 16:24:11.395536
# 15                   []    False  2022-02-12 16:24:17.506401
# 16  ['400625005137429']    False  2022-02-12 16:24:21.725559
# 17  ['398699351996661']    False  2022-02-12 16:24:26.456143
# 18  ['398066772059919']    False  2022-02-12 16:24:30.271748
# 19                   []    False  2022-02-12 16:24:32.664963
# 20  ['394831365716793']    False  2022-02-12 16:24:35.964793
# 21                   []    False  2022-02-12 16:24:42.513272
# 22  ['391400356059894']    False  2022-02-12 16:24:48.378018
# 23                   []    False  2022-02-12 16:24:55.467910
# 24  ['388998292966767']    False  2022-02-12 16:24:59.858836
# 25  ['378888557311074']    False  2022-02-12 16:25:04.793902
# 26  ['357454726121124']    False  2022-02-12 16:25:08.976923
# 27  ['319410229925574']    False  2022-02-12 16:25:14.091708
# 28  ['294832552383342']    False  2022-02-12 16:25:22.997719
#
#                                       header  like  love  wow care  haha
# 0                                        NaN   1.0   NaN  NaN  NaN   NaN
# 1                     Fukudon is at Fukudon.  14.0   1.0  NaN  NaN   NaN
# 2                                        NaN   9.0   NaN  NaN  NaN   NaN
# 3                     Fukudon is at Fukudon.   9.0   NaN  NaN  NaN   NaN
# 4                                        NaN   4.0   NaN  NaN  NaN   NaN
# 5                                    Fukudon   3.0   1.0  NaN  NaN   NaN
# 6                                        NaN  18.0   NaN  1.0  NaN   NaN
# 7                     Fukudon is at Fukudon.   3.0   NaN  NaN  NaN   NaN
# 8                     Fukudon is at Fukudon.   7.0   NaN  NaN  NaN   NaN
# 9                                        NaN   6.0   NaN  NaN  NaN   NaN
# 10                    Fukudon is at Fukudon.   4.0   NaN  NaN  NaN   NaN
# 11                                       NaN  39.0   1.0  NaN  NaN   NaN
# 12                                       NaN   9.0   NaN  NaN  NaN   NaN
# 13                                       NaN  12.0   NaN  NaN  NaN   NaN
# 14                                       NaN   9.0   NaN  NaN  NaN   NaN
# 15                    Fukudon is at Fukudon.  27.0   1.0  NaN  NaN   NaN
# 16                    Fukudon is at Fukudon.  10.0   NaN  NaN  NaN   NaN
# 17                    Fukudon is at Fukudon.   8.0   NaN  NaN  NaN   NaN
# 18                                       NaN  12.0   NaN  NaN  NaN   NaN
# 19                                       NaN   2.0   NaN  NaN  NaN   NaN
# 20                                       NaN   7.0   NaN  NaN  NaN   NaN
# 21                    Fukudon is at Fukudon.  34.0   1.0  NaN  NaN   NaN
# 22                    Fukudon is at Fukudon.  39.0   1.0  NaN  1.0   NaN
# 23                    Fukudon is at Fukudon.  45.0   NaN  NaN  NaN   2.0
# 24                                       NaN  17.0   1.0  NaN  NaN   NaN
# 25                    Fukudon is at Fukudon.  19.0   2.0  NaN  NaN   NaN
# 26                    Fukudon is at Fukudon.  18.0   1.0  NaN  1.0   NaN
# 27  Fukudon is in Marine Parade Food Centre.   1.0   NaN  NaN  NaN   NaN
# 28                                       NaN  31.0   2.0  1.0  1.0   NaN
#
# [29 rows x 55 columns]

# %%
# Perform basic line plot to visualize post datetime vs Like, Love, Ha Ha, Wow, Sad, Angry,
# Care, shares and comments
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['like'], label = "Like", marker="o")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['love'], label = "Love", marker="o")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['haha'], label = "Ha Ha", marker="o")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['wow'], label = "Wow", marker="o")
# ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['sad'], label = "Sad", marker="o")
# ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['angry'], label = "Angry", marker="o")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['care'], label = "Care", marker="o")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['shares'], label = "Shares", marker="s")
ax.plot(post_df_full_csv_with_reactions['time'], post_df_full_csv_with_reactions['comments'], label = "Comments", marker="*")
plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
# Select and display post_text & Like, Love, Ha Ha, Wow, Sad, Angry, Care, Shares and Comments columns. 
post_df_full_csv_with_reactions[['post_text','like','love','haha','wow','care',
                                 'shares','comments']]
# Out:
#                                             post_text  like  love  haha  wow  \
# 0   🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...   1.0   NaN   NaN  NaN
# 1   Let us bring you behind the scenes and show yo...  14.0   1.0   NaN  NaN
# 2   🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...   9.0   NaN   NaN  NaN
# 3   We’ve heard you! We are pleased to finally ann...   9.0   NaN   NaN  NaN
# 4   🐯🧧 Let us usher in a Roarsome Lunar New Year t...   4.0   NaN   NaN  NaN
# 5                                                 NaN   3.0   1.0   NaN  NaN
# 6   🧧Introducing to you our Roaring Combo this Lun...  18.0   NaN   NaN  1.0
# 7   In Celebration of Lunar New Year 2022, kindly ...   3.0   NaN   NaN  NaN
# 8   Take a look at our Shoyu Glazed Salmon Don, a ...   7.0   NaN   NaN  NaN
# 9   A unique take on our classic Chicken Karaage, ...   6.0   NaN   NaN  NaN
# 10  Simple but mouth-watering is the perfect way t...   4.0   NaN   NaN  NaN
# 11  Stay Home and Makan! 🤤\n\nFeast with your fami...  39.0   1.0   NaN  NaN
# 12  Wondering how to get to our Punggol outlet by ...   9.0   NaN   NaN  NaN
# 13  We would like to thank each and everyone of yo...  12.0   NaN   NaN  NaN
# 14  Wondering how to get to our Punggol outlet by ...   9.0   NaN   NaN  NaN
# 15  Aburi Miso Salmon Don w/ Pickled Cucumber, Car...  27.0   1.0   NaN  NaN
# 16  From all of us at Fukudon, we wish everyone a ...  10.0   NaN   NaN  NaN
# 17  Merry Christmas and Happy New Year to everyone...   8.0   NaN   NaN  NaN
# 18  Merry Christmas and Happy Holidays to all from...  12.0   NaN   NaN  NaN
# 19                                                NaN   2.0   NaN   NaN  NaN
# 20  We are proud to announce Fúkudon's grand openi...   7.0   NaN   NaN  NaN
# 21  We have heard you!\nA popular blackboard menu ...  34.0   1.0   NaN  NaN
# 22  Finally, the news you’ve all been waiting for....  39.0   1.0   NaN  NaN
# 23  A fan favourite, our Chicken Oyakodon is the p...  45.0   NaN   2.0  NaN
# 24  Something special is in the works for Fúkudon!...  17.0   1.0   NaN  NaN
# 25  Satay Pork Collar Onigiri, Homemade Achar and ...  19.0   2.0   NaN  NaN
# 26  Our Blackboards are back by popular demands! 🙌...  18.0   1.0   NaN  NaN
# 27  Introducing to you our newest BLACKBOARD menu ...   1.0   NaN   NaN  NaN
# 28  It's always a delightful moment when neighbori...  31.0   2.0   NaN  1.0
#
#     care  shares  comments
# 0    NaN       0         0
# 1    NaN       7         0
# 2    NaN       4         0
# 3    NaN       9         0
# 4    NaN       3         0
# 5    NaN       1         0
# 6    NaN      12         0
# 7    NaN       0         0
# 8    NaN      12         1
# 9    NaN       2         1
# 10   NaN       2         0
# 11   NaN      38         0
# 12   NaN       7         0
# 13   NaN       4         0
# 14   NaN       8         0
# 15   NaN       6         0
# 16   NaN       0         0
# 17   NaN       7         0
# 18   NaN      11         0
# 19   NaN       0         0
# 20   NaN       4         0
# 21   NaN      25         3
# 22   1.0      23         0
# 23   NaN       3         0
# 24   NaN       9         0
# 25   NaN      14         2
# 26   1.0       7         1
# 27   NaN      21         3
# 28   1.0       4         0

# %%
# Display Like, Love, Ha Ha, Wow, Sad, Angry, Care columns relationship with Shares
print(post_df_full_csv_with_reactions[['like','love','haha','wow','sad','angry','care']].corrwith(post_df_full_csv_with_reactions['shares']))
# Out:
# like     0.563059
# love     0.132927
# haha     0.686137
# wow      0.815509
# sad      0.362645
# angry    0.091397
# care     0.090059
# dtype: float64

# %%
# Display Like, Love, Ha Ha, Wow, Sad, Angry, Care columns relationship with Comments
print(post_df_full_csv_with_reactions[['like','love','haha','wow','sad','angry','care']].corrwith(post_df_full_csv_with_reactions['comments']))
# Out:
# like     0.510372
# love     0.063191
# haha     0.957203
# wow      0.480661
# sad     -0.042290
# angry    0.164824
# care     0.098893
# dtype: float64

# %% [markdown]
# Text Analytics (Sentiment Analysis) of Post Text content dataframe.

# %%
# Import necessary libraries
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# %%
# Define the service key and endpoint of Azure Text Analytics
#key = "PLEASE_ENTER_YOUR_OWNED_AZURE_TEXT_ANALYTICS_SERVICE_KEY"
#endpoint = "https://PLEASE_ENTER_YOUR_OWNED_AZURE_TEXT_ANALYTICS_INSTANCE_NAME.cognitiveservices.azure.com/"

# %%
# Configure Azure Text Analytics client library
ta_credential = AzureKeyCredential(key)
text_analytics_client = TextAnalyticsClient(
        endpoint=endpoint, 
        credential=ta_credential)
client = text_analytics_client

post_df_post_text_sentiment = []
key_phrase_extract = []

# Pass post text content to Azure Text Analytics and collect sentiment result
for index, headers in post_df_full_csv_with_reactions.iterrows():
    post_text_content = str(headers['post_text'])
    print("Post Text Content: {}".format(post_text_content))
    documents = [post_text_content]
    response = client.analyze_sentiment(documents=documents, language="en")[0]
    sentiment = response.sentiment
    print("Post Text Content Sentiment: {}".format(sentiment))
    like = str(headers['like'])
    print("Number of Like: {}".format(like))
    love = str(headers['love'])
    print("Number of Love: {}".format(love))
    haha = str(headers['haha'])
    print("Number of Ha Ha: {}".format(haha))
    wow = str(headers['wow'])
    print("Number of WoW: {}".format(wow))
    sad = str(headers['sad'])
    print("Number of Sad: {}".format(sad))
    angry = str(headers['angry'])
    print("Number of Angry: {}".format(angry))
    care = str(headers['care'])
    print("Number of Care: {}".format(care))
    shares = str(headers['shares'])
    print("Number of Shares: {}".format(shares))
    comments = str(headers['comments'])
    print("Number of Comments: {}".format(comments))
    response_ekp = client.extract_key_phrases(documents = documents)[0]
    for phrase in response_ekp.key_phrases:
                #print("Key phrase: {}".format(phrase))
                key_phrase_extract.append(phrase)
                print(key_phrase_extract)
    
    post_df_post_text_sentiment.append([post_text_content, sentiment, like, love, haha, wow, 
                                        sad, angry, care, shares, comments, key_phrase_extract])
    
    key_phrase_extract = []

# Convert collected post text content with sentiment to Pandas dataframes.
post_df_post_text_sentiment = pd.DataFrame(post_df_post_text_sentiment, columns=['post_text','sentiment',
                                                                                 'like','love','haha',
                                                                                'wow','sad','angry',
                                                                                'care','shares','comments','key_phrase_extract'])
# Out:
# Post Text Content: An unprecedented challenge made by Poland's prime minister, Mateusz Morawiecki, has escalated his government's dispute with Brussels.
# Post Text Content Sentiment: negative
# Number of Like: 218.0
# Number of Love: 36.0
# Number of Ha Ha: 57.0
# Number of WoW: 10.0
# Number of Sad: 10.0
# Number of Angry: 4.0
# Number of Care: nan
# Number of Shares: 28
# Number of Comments: 204
# ['unprecedented challenge']
# ['unprecedented challenge', 'prime minister']
# ['unprecedented challenge', 'prime minister', 'Mateusz Morawiecki']
# ['unprecedented challenge', 'prime minister', 'Mateusz Morawiecki', 'Poland']
# ['unprecedented challenge', 'prime minister', 'Mateusz Morawiecki', 'Poland', 'government']
# ['unprecedented challenge', 'prime minister', 'Mateusz Morawiecki', 'Poland', 'government', 'dispute']
# ['unprecedented challenge', 'prime minister', 'Mateusz Morawiecki', 'Poland', 'government', 'dispute', 'Brussels']
# Post Text Content: "Thoughout the pandemic we have no been training HGV drivers."
#
# Conservative peer Peter Lilley and Local Authority Recycling Advisory Committee CEO Lee Marshall discuss the on-going HGV driver shortage,
#
# bbc.in/3DiZ5Si BBC Newsnight
# Post Text Content Sentiment: neutral
# Number of Like: 173.0
# Number of Love: nan
# Number of Ha Ha: 5.0
# Number of WoW: 1.0
# Number of Sad: 2.0
# Number of Angry: nan
# Number of Care: 1.0
# Number of Shares: 26
# Number of Comments: 107
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall']
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall', 'Conservative peer Peter Lilley']
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall', 'Conservative peer Peter Lilley', 'DiZ5Si BBC Newsnight']
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall', 'Conservative peer Peter Lilley', 'DiZ5Si BBC Newsnight', 'HGV driver shortage']
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall', 'Conservative peer Peter Lilley', 'DiZ5Si BBC Newsnight', 'HGV driver shortage', 'HGV drivers']
# ['Local Authority Recycling Advisory Committee CEO Lee Marshall', 'Conservative peer Peter Lilley', 'DiZ5Si BBC Newsnight', 'HGV driver shortage', 'HGV drivers', 'pandemic']
# Post Text Content: "The safety of the audience and touring crew has to take priority."
# Post Text Content Sentiment: neutral
# Number of Like: 699.0
# Number of Love: 14.0
# Number of Ha Ha: 11.0
# Number of WoW: 28.0
# Number of Sad: 293.0
# Number of Angry: 1.0
# Number of Care: 121.0
# Number of Shares: 100
# Number of Comments: 334
# ['touring crew']
# ['touring crew', 'safety']
# ['touring crew', 'safety', 'audience']
# ['touring crew', 'safety', 'audience', 'priority']
# Post Text Content: "If you think you have Covid, even if the PCR is coming back as negative, regard it as Covid and self-isolate," a UK director of public health has said.
# Post Text Content Sentiment: negative
# Number of Like: 4761.0
# Number of Love: 63.0
# Number of Ha Ha: 4359.0
# Number of WoW: 444.0
# Number of Sad: 46.0
# Number of Angry: 165.0
# Number of Care: 31.0
# Number of Shares: 3500
# Number of Comments: 4700
# ['UK director']
# ['UK director', 'public health']
# ['UK director', 'public health', 'Covid']
# ['UK director', 'public health', 'Covid', 'PCR']
# Post Text Content: "This could have been fatal."
# Post Text Content Sentiment: negative
# Number of Like: 446.0
# Number of Love: 4.0
# Number of Ha Ha: 4.0
# Number of WoW: 71.0
# Number of Sad: 163.0
# Number of Angry: 1256.0
# Number of Care: 1.0
# Number of Shares: 804
# Number of Comments: 613
# Post Text Content: Nicole Jack, who joined IS in 2015 with her children, said UK politicians should "open your minds" to allowing them to return from Syria.
# Post Text Content Sentiment: neutral
# Number of Like: 923.0
# Number of Love: 9.0
# Number of Ha Ha: 1871.0
# Number of WoW: 49.0
# Number of Sad: 25.0
# Number of Angry: 672.0
# Number of Care: 7.0
# Number of Shares: 100
# Number of Comments: 2300
# ['Nicole Jack']
# ['Nicole Jack', 'UK politicians']
# ['Nicole Jack', 'UK politicians', 'IS']
# ['Nicole Jack', 'UK politicians', 'IS', 'children']
# ['Nicole Jack', 'UK politicians', 'IS', 'children', 'minds']
# ['Nicole Jack', 'UK politicians', 'IS', 'children', 'minds', 'Syria']
# Post Text Content: "There are many magical events happening in nature around us - I was just being curious and observant."
# Post Text Content Sentiment: positive
# Number of Like: 346.0
# Number of Love: 19.0
# Number of Ha Ha: nan
# Number of WoW: 9.0
# Number of Sad: nan
# Number of Angry: 1.0
# Number of Care: 1.0
# Number of Shares: 40
# Number of Comments: 26
# ['many magical events']
# ['many magical events', 'nature']
# Post Text Content: "When the protests got bigger, friends and family were sending me money, and I was using it to cater for the protesters. I made food for almost 2,000 people single-handed."
# Post Text Content Sentiment: negative
# Number of Like: 240.0
# Number of Love: 4.0
# Number of Ha Ha: 2.0
# Number of WoW: 3.0
# Number of Sad: nan
# Number of Angry: nan
# Number of Care: 13.0
# Number of Shares: 21
# Number of Comments: 64
# ['protests']
# ['protests', 'friends']
# ['protests', 'friends', 'family']
# ['protests', 'friends', 'family', 'money']
# ['protests', 'friends', 'family', 'money', 'protesters']
# ['protests', 'friends', 'family', 'money', 'protesters', 'food']
# ['protests', 'friends', 'family', 'money', 'protesters', 'food', '2,000 people']
# Post Text Content: As fashion brands continue to overproduce to meet demands, countries in West Africa are said to be drowning under the weight of waste shipped to their stores.
#
# https://bbc.in/3aj5Kj5
# Post Text Content Sentiment: negative
# Number of Like: 1434.0
# Number of Love: 16.0
# Number of Ha Ha: 45.0
# Number of WoW: 622.0
# Number of Sad: 1556.0
# Number of Angry: 265.0
# Number of Care: 15.0
# Number of Shares: 2100
# Number of Comments: 668
# ['fashion brands']
# ['fashion brands', 'West Africa']
# ['fashion brands', 'West Africa', 'demands']
# ['fashion brands', 'West Africa', 'demands', 'countries']
# ['fashion brands', 'West Africa', 'demands', 'countries', 'weight']
# ['fashion brands', 'West Africa', 'demands', 'countries', 'weight', 'waste']
# ['fashion brands', 'West Africa', 'demands', 'countries', 'weight', 'waste', 'stores']
# ['fashion brands', 'West Africa', 'demands', 'countries', 'weight', 'waste', 'stores', 'bbc']
# ['fashion brands', 'West Africa', 'demands', 'countries', 'weight', 'waste', 'stores', 'bbc', 'aj5Kj5']
# Post Text Content: Two diamond and emerald spectacles from an unknown Indian princely treasury are to be sold in October.
# Post Text Content Sentiment: neutral
# Number of Like: 957.0
# Number of Love: 48.0
# Number of Ha Ha: 14.0
# Number of WoW: 249.0
# Number of Sad: 3.0
# Number of Angry: 8.0
# Number of Care: 3.0
# Number of Shares: 145
# Number of Comments: 218
# ['unknown Indian princely treasury']
# ['unknown Indian princely treasury', 'Two diamond']
# ['unknown Indian princely treasury', 'Two diamond', 'emerald spectacles']
# ['unknown Indian princely treasury', 'Two diamond', 'emerald spectacles', 'October']
# Post Text Content: The statue at the University of Hong Kong commemorates the 1989 Tiananmen Square massacre.
# Post Text Content Sentiment: neutral
# Number of Like: 1708.0
# Number of Love: 35.0
# Number of Ha Ha: 58.0
# Number of WoW: 117.0
# Number of Sad: 914.0
# Number of Angry: 2048.0
# Number of Care: 21.0
# Number of Shares: 495
# Number of Comments: 959
# ['1989 Tiananmen Square massacre']
# ['1989 Tiananmen Square massacre', 'Hong Kong']
# ['1989 Tiananmen Square massacre', 'Hong Kong', 'statue']
# ['1989 Tiananmen Square massacre', 'Hong Kong', 'statue', 'University']
# Post Text Content: The former president had previously claimed the hotel earned $150m during his four year term.
# Post Text Content Sentiment: neutral
# Number of Like: 925.0
# Number of Love: 58.0
# Number of Ha Ha: 1402.0
# Number of WoW: 46.0
# Number of Sad: 20.0
# Number of Angry: 11.0
# Number of Care: 8.0
# Number of Shares: 122
# Number of Comments: 934
# ['four year term']
# ['four year term', 'former president']
# ['four year term', 'former president', 'hotel']
# Post Text Content: 136 countries have agreed to enforce a corporate tax rate of at least 15%, as well as a fairer system of taxing profits where they are earned.
# Post Text Content Sentiment: positive
# Number of Like: 7790.0
# Number of Love: 769.0
# Number of Ha Ha: 173.0
# Number of WoW: 42.0
# Number of Sad: 17.0
# Number of Angry: 75.0
# Number of Care: 23.0
# Number of Shares: 893
# Number of Comments: 860
# ['corporate tax rate']
# ['corporate tax rate', 'fairer system']
# ['corporate tax rate', 'fairer system', '136 countries']
# ['corporate tax rate', 'fairer system', '136 countries', 'profits']
# Post Text Content: Russia's justice ministry said it was adding nine journalists and three companies to the foreign agent list.
# Post Text Content Sentiment: neutral
# Number of Like: 248.0
# Number of Love: 7.0
# Number of Ha Ha: 72.0
# Number of WoW: 17.0
# Number of Sad: 20.0
# Number of Angry: 89.0
# Number of Care: nan
# Number of Shares: 71
# Number of Comments: 110
# ['foreign agent list']
# ['foreign agent list', 'justice ministry']
# ['foreign agent list', 'justice ministry', 'nine journalists']
# ['foreign agent list', 'justice ministry', 'nine journalists', 'three companies']
# ['foreign agent list', 'justice ministry', 'nine journalists', 'three companies', 'Russia']
# Post Text Content: BBC journalists who know Maria Ressa and Dmitry Muratov share their experiences of working with them.
# Post Text Content Sentiment: neutral
# Number of Like: 275.0
# Number of Love: 15.0
# Number of Ha Ha: 71.0
# Number of WoW: nan
# Number of Sad: nan
# Number of Angry: 3.0
# Number of Care: 2.0
# Number of Shares: 54
# Number of Comments: 150
# ['BBC journalists']
# ['BBC journalists', 'Maria Ressa']
# ['BBC journalists', 'Maria Ressa', 'Dmitry Muratov']
# ['BBC journalists', 'Maria Ressa', 'Dmitry Muratov', 'experiences']
# Post Text Content: "To build physical schools around the world would cost billions, with smartphones we can reach two-thirds of the human population."
# Post Text Content Sentiment: neutral
# Number of Like: 481.0
# Number of Love: 76.0
# Number of Ha Ha: 5.0
# Number of WoW: 9.0
# Number of Sad: nan
# Number of Angry: 1.0
# Number of Care: 4.0
# Number of Shares: 71
# Number of Comments: 39
# ['physical schools']
# ['physical schools', 'human population']
# ['physical schools', 'human population', 'world']
# ['physical schools', 'human population', 'world', 'billions']
# ['physical schools', 'human population', 'world', 'billions', 'smartphones']
# ['physical schools', 'human population', 'world', 'billions', 'smartphones', 'two-thirds']
# Post Text Content: Micro Van Goghs, a Munch and others small enough to fit into the eye of a needle.
# Post Text Content Sentiment: neutral
# Number of Like: 229.0
# Number of Love: 17.0
# Number of Ha Ha: 5.0
# Number of WoW: 53.0
# Number of Sad: 1.0
# Number of Angry: 1.0
# Number of Care: nan
# Number of Shares: 46
# Number of Comments: 67
# ['Micro Van Goghs']
# ['Micro Van Goghs', 'Munch']
# ['Micro Van Goghs', 'Munch', 'others']
# ['Micro Van Goghs', 'Munch', 'others', 'eye']
# ['Micro Van Goghs', 'Munch', 'others', 'eye', 'needle']
# Post Text Content: The new outage comes just days after Instagram, Facebook and WhatsApp were down for nearly six hours.
# Post Text Content Sentiment: neutral
# Number of Like: 2202.0
# Number of Love: 36.0
# Number of Ha Ha: 494.0
# Number of WoW: 150.0
# Number of Sad: 20.0
# Number of Angry: 39.0
# Number of Care: 11.0
# Number of Shares: 251
# Number of Comments: 357
# ['new outage']
# ['new outage', 'six hours']
# ['new outage', 'six hours', 'Instagram']
# ['new outage', 'six hours', 'Instagram', 'Facebook']
# ['new outage', 'six hours', 'Instagram', 'Facebook', 'WhatsApp']

# %%
# Display newly created dataframe with sentiment analysis and key phrase extraction result
post_df_post_text_sentiment
# Out:
#                                             post_text sentiment    like  \
# 0   An unprecedented challenge made by Poland's pr...  negative   218.0
# 1   "Thoughout the pandemic we have no been traini...   neutral   173.0
# 2   "The safety of the audience and touring crew h...   neutral   699.0
# 3   "If you think you have Covid, even if the PCR ...  negative  4761.0
# 4                       "This could have been fatal."  negative   446.0
# 5   Nicole Jack, who joined IS in 2015 with her ch...   neutral   923.0
# 6   "There are many magical events happening in na...  positive   346.0
# 7   "When the protests got bigger, friends and fam...  negative   240.0
# 8   As fashion brands continue to overproduce to m...  negative  1434.0
# 9   Two diamond and emerald spectacles from an unk...   neutral   957.0
# 10  The statue at the University of Hong Kong comm...   neutral  1708.0
# 11  The former president had previously claimed th...   neutral   925.0
# 12  136 countries have agreed to enforce a corpora...  positive  7790.0
# 13  Russia's justice ministry said it was adding n...   neutral   248.0
# 14  BBC journalists who know Maria Ressa and Dmitr...   neutral   275.0
# 15  "To build physical schools around the world wo...   neutral   481.0
# 16  Micro Van Goghs, a Munch and others small enou...   neutral   229.0
# 17  The new outage comes just days after Instagram...   neutral  2202.0
#
#      love    haha    wow     sad   angry   care shares comments  \
# 0    36.0    57.0   10.0    10.0     4.0    nan     28      204
# 1     nan     5.0    1.0     2.0     nan    1.0     26      107
# 2    14.0    11.0   28.0   293.0     1.0  121.0    100      334
# 3    63.0  4359.0  444.0    46.0   165.0   31.0   3500     4700
# 4     4.0     4.0   71.0   163.0  1256.0    1.0    804      613
# 5     9.0  1871.0   49.0    25.0   672.0    7.0    100     2300
# 6    19.0     nan    9.0     nan     1.0    1.0     40       26
# 7     4.0     2.0    3.0     nan     nan   13.0     21       64
# 8    16.0    45.0  622.0  1556.0   265.0   15.0   2100      668
# 9    48.0    14.0  249.0     3.0     8.0    3.0    145      218
# 10   35.0    58.0  117.0   914.0  2048.0   21.0    495      959
# 11   58.0  1402.0   46.0    20.0    11.0    8.0    122      934
# 12  769.0   173.0   42.0    17.0    75.0   23.0    893      860
# 13    7.0    72.0   17.0    20.0    89.0    nan     71      110
# 14   15.0    71.0    nan     nan     3.0    2.0     54      150
# 15   76.0     5.0    9.0     nan     1.0    4.0     71       39
# 16   17.0     5.0   53.0     1.0     1.0    nan     46       67
# 17   36.0   494.0  150.0    20.0    39.0   11.0    251      357
#
#                                    key_phrase_extract
# 0   [unprecedented challenge, prime minister, Mate...
# 1   [Local Authority Recycling Advisory Committee ...
# 2          [touring crew, safety, audience, priority]
# 3            [UK director, public health, Covid, PCR]
# 4                                                  []
# 5   [Nicole Jack, UK politicians, IS, children, mi...
# 6                       [many magical events, nature]
# 7   [protests, friends, family, money, protesters,...
# 8   [fashion brands, West Africa, demands, countri...
# 9   [unknown Indian princely treasury, Two diamond...
# 10  [1989 Tiananmen Square massacre, Hong Kong, st...
# 11          [four year term, former president, hotel]
# 12  [corporate tax rate, fairer system, 136 countr...
# 13  [foreign agent list, justice ministry, nine jo...
# 14  [BBC journalists, Maria Ressa, Dmitry Muratov,...
# 15  [physical schools, human population, world, bi...
# 16      [Micro Van Goghs, Munch, others, eye, needle]
# 17  [new outage, six hours, Instagram, Facebook, W...

# %%
# Create new dataframe to perform factorization
post_df_post_text_sentiment_factorized = post_df_post_text_sentiment.copy()

# %%
# Perform factorization for sentiment column
post_df_post_text_sentiment_factorized.sentiment = pd.factorize(post_df_post_text_sentiment_factorized.sentiment)[0]

# %%
# Change columns back to correct datatype
post_df_post_text_sentiment_factorized['like'] = post_df_post_text_sentiment_factorized['like'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['love'] = post_df_post_text_sentiment_factorized['love'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['haha'] = post_df_post_text_sentiment_factorized['haha'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['wow'] = post_df_post_text_sentiment_factorized['wow'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['sad'] = post_df_post_text_sentiment_factorized['sad'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['angry'] = post_df_post_text_sentiment_factorized['angry'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['care'] = post_df_post_text_sentiment_factorized['care'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['shares'] = post_df_post_text_sentiment_factorized['shares'].fillna(0).astype('float64')
post_df_post_text_sentiment_factorized['comments'] = post_df_post_text_sentiment_factorized['comments'].fillna(0).astype('float64')

# %%
# Display factorized sentiment dataframe, 0 = Negative, 1 = Neutral, 2 = Positive
post_df_post_text_sentiment_factorized
# Out:
#                                             post_text  sentiment    like  \
# 0   An unprecedented challenge made by Poland's pr...          0   218.0
# 1   "Thoughout the pandemic we have no been traini...          1   173.0
# 2   "The safety of the audience and touring crew h...          1   699.0
# 3   "If you think you have Covid, even if the PCR ...          0  4761.0
# 4                       "This could have been fatal."          0   446.0
# 5   Nicole Jack, who joined IS in 2015 with her ch...          1   923.0
# 6   "There are many magical events happening in na...          2   346.0
# 7   "When the protests got bigger, friends and fam...          0   240.0
# 8   As fashion brands continue to overproduce to m...          0  1434.0
# 9   Two diamond and emerald spectacles from an unk...          1   957.0
# 10  The statue at the University of Hong Kong comm...          1  1708.0
# 11  The former president had previously claimed th...          1   925.0
# 12  136 countries have agreed to enforce a corpora...          2  7790.0
# 13  Russia's justice ministry said it was adding n...          1   248.0
# 14  BBC journalists who know Maria Ressa and Dmitr...          1   275.0
# 15  "To build physical schools around the world wo...          1   481.0
# 16  Micro Van Goghs, a Munch and others small enou...          1   229.0
# 17  The new outage comes just days after Instagram...          1  2202.0
#
#      love    haha    wow     sad   angry   care  shares  comments  \
# 0    36.0    57.0   10.0    10.0     4.0    NaN    28.0     204.0
# 1     NaN     5.0    1.0     2.0     NaN    1.0    26.0     107.0
# 2    14.0    11.0   28.0   293.0     1.0  121.0   100.0     334.0
# 3    63.0  4359.0  444.0    46.0   165.0   31.0  3500.0    4700.0
# 4     4.0     4.0   71.0   163.0  1256.0    1.0   804.0     613.0
# 5     9.0  1871.0   49.0    25.0   672.0    7.0   100.0    2300.0
# 6    19.0     NaN    9.0     NaN     1.0    1.0    40.0      26.0
# 7     4.0     2.0    3.0     NaN     NaN   13.0    21.0      64.0
# 8    16.0    45.0  622.0  1556.0   265.0   15.0  2100.0     668.0
# 9    48.0    14.0  249.0     3.0     8.0    3.0   145.0     218.0
# 10   35.0    58.0  117.0   914.0  2048.0   21.0   495.0     959.0
# 11   58.0  1402.0   46.0    20.0    11.0    8.0   122.0     934.0
# 12  769.0   173.0   42.0    17.0    75.0   23.0   893.0     860.0
# 13    7.0    72.0   17.0    20.0    89.0    NaN    71.0     110.0
# 14   15.0    71.0    NaN     NaN     3.0    2.0    54.0     150.0
# 15   76.0     5.0    9.0     NaN     1.0    4.0    71.0      39.0
# 16   17.0     5.0   53.0     1.0     1.0    NaN    46.0      67.0
# 17   36.0   494.0  150.0    20.0    39.0   11.0   251.0     357.0
#
#                                    key_phrase_extract
# 0   [unprecedented challenge, prime minister, Mate...
# 1   [Local Authority Recycling Advisory Committee ...
# 2          [touring crew, safety, audience, priority]
# 3            [UK director, public health, Covid, PCR]
# 4                                                  []
# 5   [Nicole Jack, UK politicians, IS, children, mi...
# 6                       [many magical events, nature]
# 7   [protests, friends, family, money, protesters,...
# 8   [fashion brands, West Africa, demands, countri...
# 9   [unknown Indian princely treasury, Two diamond...
# 10  [1989 Tiananmen Square massacre, Hong Kong, st...
# 11          [four year term, former president, hotel]
# 12  [corporate tax rate, fairer system, 136 countr...
# 13  [foreign agent list, justice ministry, nine jo...
# 14  [BBC journalists, Maria Ressa, Dmitry Muratov,...
# 15  [physical schools, human population, world, bi...
# 16      [Micro Van Goghs, Munch, others, eye, needle]
# 17  [new outage, six hours, Instagram, Facebook, W...

# %%
# Plotting sentiment & Like columns relationship by Seaborn
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
plt.title('Statistical Analysis by Sentiment Score and Number of Like', fontsize=10)
sns.regplot(x='sentiment', y= 'like', data=post_df_post_text_sentiment_factorized)
sns.despine()

# %%
# Plotting sentiment & Shares columns relationship by Seaborn
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
plt.title('Statistical Analysis by Sentiment Score and Number of Shares', fontsize=10)
sns.regplot(x='sentiment', y= 'shares', data=post_df_post_text_sentiment_factorized)
sns.despine()

# %%
# Plotting sentiment & Comments columns relationship by Seaborn
fig, ax = plt.subplots()
fig.set_size_inches(12, 8)
plt.title('Statistical Analysis by Sentiment Score and Number of Comments', fontsize=10)
sns.regplot(x='sentiment', y= 'comments', data=post_df_post_text_sentiment_factorized)
sns.despine()

# %%
# Import WordCloud library for wordcloud generation
from wordcloud import WordCloud

# %%
# Plot WordCloud with Matplotlib
text = post_df_post_text_sentiment_factorized['key_phrase_extract'].values
text_a = str(text).replace('list', '')

wordcloud = WordCloud(width = 500, height = 500, 
            background_color ='white',
            min_font_size = 10).generate(str(text_a)) 

plt.figure(figsize = (15, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
