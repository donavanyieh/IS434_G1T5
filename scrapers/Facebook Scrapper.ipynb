# %%
pip install git+https://github.com/kevinzg/facebook-scraper.git
# Out:
# ...
#   Cloning https://github.com/kevinzg/facebook-scraper.git to c:\users\kytan\appdata\local\temp\pip-req-build-ol5m26s7
#   Resolved https://github.com/kevinzg/facebook-scraper.git to commit 7357da290aa1454bafe74418fa90427a274f1e49
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none -q https://github.com/kevinzg/facebook-scraper.git 'C:\Users\kytan\AppData\Local\Temp\pip-req-build-ol5m26s7'
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\kytan\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Import necessary libraries
from facebook_scraper import get_posts
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns = [])

# %%
# Start to collect Facebook post data by facebook_scraper library

# use your own cookies --> you can add chrome extension getcookies to save cookies in txt file 
for post in get_posts('fukudonsg', cookies='facebook.com_cookies2.txt', extra_info=True, pages=8, options={"comments": True}):
    post_entry = post
    fb_post_df = pd.DataFrame.from_dict(post_entry, orient='index')
    fb_post_df = fb_post_df.transpose()
    post_df_full = post_df_full.append(fb_post_df)
    print(post['post_id']+' get')
# Out:
# 430656518800944 get
# C:\Users\kytan\anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py:795: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(
# C:\Users\kytan\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# 427687089097887 get
# 425210366012226 get
# 421822059684390 get
# 420517959814800 get
# 419646406568622 get
# 418761639990432 get
# 418118486721414 get
# 415699836963279 get
# 413257057207557 get
# 411993977333865 get
# 407776717755591 get
# 407201737813089 get
# 404827634717166 get
# 403586801507916 get
# 401825905017339 get
# 400625021804094 get
# 398699378663325 get
# 398066788726584 get
# 394841922382404 get
# 394831389050124 get
# ...

# %%
# Check dataframe information
post_df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 0
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        29 non-null     object
#  1   text                           29 non-null     object
#  2   post_text                      29 non-null     object
#  3   shared_text                    29 non-null     object
#  4   time                           29 non-null     datetime64[ns]
#  5   timestamp                      8 non-null      object
#  6   image                          24 non-null     object
#  7   image_lowquality               29 non-null     object
#  8   images                         29 non-null     object
#  9   images_description             29 non-null     object
#  10  images_lowquality              29 non-null     object
#  11  images_lowquality_description  29 non-null     object
# ...

# %%
# Display header of dataframe
post_df_full.head()
# Out:
#            post_id                                               text  \
# 0  430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 0  427687089097887  Let us bring you behind the scenes and show yo...
# 0  425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 0  421822059684390  We’ve heard you! We are pleased to finally ann...
# 0  420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                                            post_text shared_text  \
# 0  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 0  Let us bring you behind the scenes and show yo...
# 0  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 0  We’ve heard you! We are pleased to finally ann...
# 0  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
#
#                  time timestamp  \
# 0 2022-02-12 14:14:07      None
# 0 2022-02-07 15:20:00      None
# 0 2022-02-03 11:24:00      None
# 0 2022-01-28 18:04:00      None
# 0 2022-01-26 13:37:00      None
#
# ...

# %%
post_df_full
# Out:
#            post_id                                               text  \
# 0  430656518800944  🥚🥚Attention all egg lovers! 🥚🥚\n\nWe have a sp...
# 0  427687089097887  Let us bring you behind the scenes and show yo...
# 0  425210366012226  🐯新年快乐 恭喜发财🍊\n\nFrom all of us at Fúkudon, we w...
# 0  421822059684390  We’ve heard you! We are pleased to finally ann...
# 0  420517959814800  🐯🧧 Let us usher in a Roarsome Lunar New Year t...
# 0  419646406568622  OutlandishSG\nJanuary 24 at 8:00 PM ·\n\nJapan...
# 0  418761639990432  🧧Introducing to you our Roaring Combo this Lun...
# 0  418118486721414  In Celebration of Lunar New Year 2022, kindly ...
# 0  415699836963279  Take a look at our Shoyu Glazed Salmon Don, a ...
# 0  413257057207557  A unique take on our classic Chicken Karaage, ...
# 0  411993977333865  Simple but mouth-watering is the perfect way t...
# 0  407776717755591  Stay Home and Makan! 🤤\n\nFeast with your fami...
# ...

# %%
# Save dataframe into csv file
post_df_full.to_csv(r'fb_scrapped_data.csv', index = False)
